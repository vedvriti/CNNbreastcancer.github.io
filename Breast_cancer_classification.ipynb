# %% [markdown]
# # Loading & Preprocessing

# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications import ResNet50 ,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools


# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

benign_train = np.array(Dataset_loader('/content/drive/MyDrive/benign21',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/malignant',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/benign21',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/malignant',224))
# Out:
# 100%|██████████| 526/526 [00:09<00:00, 54.22it/s]
# 100%|██████████| 421/421 [00:06<00:00, 61.65it/s]
# 100%|██████████| 526/526 [00:03<00:00, 175.02it/s]
# 100%|██████████| 421/421 [00:02<00:00, 164.98it/s]

# %% [markdown]
# # Create Label

# %%
# Skin Cancer: Malignant vs. Benign
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# Merge data 
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# To categorical
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)

# %% [markdown]
# # Train and Evalutation split

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train, 
    test_size=0.2, 
    random_state=11
)

# %% [markdown]
# # Display Some Images

# %%
# # Display first 15 images of moles, and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %% [markdown]
# # Data Generator

# %%
BATCH_SIZE = 16

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True,  # randomly flip images
    )

# %% [markdown]
# # Model: ResNet50

# %%
def build_model(backbone, lr=1e-4):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(2, activation='sigmoid'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['accuracy']
    )
    
    return model

# %%
K.clear_session()
gc.collect()

resnet = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)


 


model = build_model(resnet ,lr = 1e-4)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1920)              0
#
#  batch_normalization (BatchN  (None, 1920)             7680
#  ormalization)
#
#  dense (Dense)               (None, 2)                 3842
#
# =================================================================
# Total params: 18,333,506
# Trainable params: 18,100,610
# Non-trainable params: 232,896
# _________________________________________________________________

# %%
# Learning Rate Reducer #callback
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,
                                  verbose=1, factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath,monitor='val_accuracy',verbose=1,save_best_only=True,mode='max')

# %% [markdown]
# # Training & Evaluation

# %%
history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=100,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/100
# 48/47 [==============================] - ETA: 0s - loss: 0.6398 - accuracy: 0.6579
# Epoch 1: val_accuracy improved from -inf to 0.84211, saving model to weights.best.hdf5
# 47/47 [==============================] - 41s 431ms/step - loss: 0.6398 - accuracy: 0.6579 - val_loss: 0.3285 - val_accuracy: 0.8421 - lr: 1.0000e-04
# Epoch 2/100
# 48/47 [==============================] - ETA: 0s - loss: 0.5011 - accuracy: 0.7530
# Epoch 2: val_accuracy improved from 0.84211 to 0.88947, saving model to weights.best.hdf5
# 47/47 [==============================] - 18s 376ms/step - loss: 0.5011 - accuracy: 0.7530 - val_loss: 0.2854 - val_accuracy: 0.8895 - lr: 1.0000e-04
# Epoch 3/100
# 48/47 [==============================] - ETA: 0s - loss: 0.5044 - accuracy: 0.7609
# Epoch 3: val_accuracy did not improve from 0.88947
# 47/47 [==============================] - 15s 320ms/step - loss: 0.5044 - accuracy: 0.7609 - val_loss: 0.2612 - val_accuracy: 0.8632 - lr: 1.0000e-04
# Epoch 4/100
# 48/47 [==============================] - ETA: 0s - loss: 0.4348 - accuracy: 0.8085
# Epoch 4: val_accuracy did not improve from 0.88947
# 47/47 [==============================] - 15s 317ms/step - loss: 0.4348 - accuracy: 0.8085 - val_loss: 0.2436 - val_accuracy: 0.8842 - lr: 1.0000e-04
# Epoch 5/100
# 48/47 [==============================] - ETA: 0s - loss: 0.4259 - accuracy: 0.8058
# Epoch 5: val_accuracy improved from 0.88947 to 0.89474, saving model to weights.best.hdf5
# 47/47 [==============================] - 17s 362ms/step - loss: 0.4259 - accuracy: 0.8058 - val_loss: 0.1989 - val_accuracy: 0.8947 - lr: 1.0000e-04
# Epoch 6/100
# 48/47 [==============================] - ETA: 0s - loss: 0.4219 - accuracy: 0.8098
# Epoch 6: val_accuracy improved from 0.89474 to 0.91579, saving model to weights.best.hdf5
# 47/47 [==============================] - 18s 369ms/step - loss: 0.4219 - accuracy: 0.8098 - val_loss: 0.2329 - val_accuracy: 0.9158 - lr: 1.0000e-04
# Epoch 7/100
# 48/47 [==============================] - ETA: 0s - loss: 0.4154 - accuracy: 0.8111
# Epoch 7: val_accuracy did not improve from 0.91579
# 47/47 [==============================] - 15s 318ms/step - loss: 0.4154 - accuracy: 0.8111 - val_loss: 0.2847 - val_accuracy: 0.8684 - lr: 1.0000e-04
# Epoch 8/100
# 48/47 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.8243
# Epoch 8: val_accuracy did not improve from 0.91579
# 47/47 [==============================] - 15s 320ms/step - loss: 0.4132 - accuracy: 0.8243 - val_loss: 0.2039 - val_accuracy: 0.9158 - lr: 1.0000e-04
# Epoch 9/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8203
# Epoch 9: val_accuracy improved from 0.91579 to 0.92105, saving model to weights.best.hdf5
# 47/47 [==============================] - 18s 384ms/step - loss: 0.3907 - accuracy: 0.8203 - val_loss: 0.1927 - val_accuracy: 0.9211 - lr: 1.0000e-04
# Epoch 10/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.8547
# Epoch 10: val_accuracy improved from 0.92105 to 0.92632, saving model to weights.best.hdf5
# 47/47 [==============================] - 21s 451ms/step - loss: 0.3614 - accuracy: 0.8547 - val_loss: 0.1876 - val_accuracy: 0.9263 - lr: 1.0000e-04
# Epoch 11/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3815 - accuracy: 0.8388
# Epoch 11: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 317ms/step - loss: 0.3815 - accuracy: 0.8388 - val_loss: 0.2445 - val_accuracy: 0.9053 - lr: 1.0000e-04
# Epoch 12/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3720 - accuracy: 0.8534
# Epoch 12: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 320ms/step - loss: 0.3720 - accuracy: 0.8534 - val_loss: 0.1832 - val_accuracy: 0.9105 - lr: 1.0000e-04
# Epoch 13/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3652 - accuracy: 0.8402
# Epoch 13: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3652 - accuracy: 0.8402 - val_loss: 0.1793 - val_accuracy: 0.9158 - lr: 1.0000e-04
# Epoch 14/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.8666
# Epoch 14: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 316ms/step - loss: 0.3433 - accuracy: 0.8666 - val_loss: 0.1908 - val_accuracy: 0.9053 - lr: 1.0000e-04
# Epoch 15/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3980 - accuracy: 0.8283
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 15: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 337ms/step - loss: 0.3980 - accuracy: 0.8283 - val_loss: 0.2153 - val_accuracy: 0.9158 - lr: 1.0000e-04
# Epoch 16/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3330 - accuracy: 0.8587
# Epoch 16: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3330 - accuracy: 0.8587 - val_loss: 0.1968 - val_accuracy: 0.9158 - lr: 2.0000e-05
# Epoch 17/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3393 - accuracy: 0.8415
# Epoch 17: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3393 - accuracy: 0.8415 - val_loss: 0.1910 - val_accuracy: 0.9053 - lr: 2.0000e-05
# Epoch 18/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3042 - accuracy: 0.8824
# Epoch 18: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3042 - accuracy: 0.8824 - val_loss: 0.2091 - val_accuracy: 0.9000 - lr: 2.0000e-05
# Epoch 19/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.8626
# Epoch 19: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3368 - accuracy: 0.8626 - val_loss: 0.2014 - val_accuracy: 0.9000 - lr: 2.0000e-05
# Epoch 20/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.8573
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 20: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3277 - accuracy: 0.8573 - val_loss: 0.2032 - val_accuracy: 0.9053 - lr: 2.0000e-05
# Epoch 21/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3107 - accuracy: 0.8547
# Epoch 21: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3107 - accuracy: 0.8547 - val_loss: 0.2035 - val_accuracy: 0.9053 - lr: 4.0000e-06
# Epoch 22/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.8811
# Epoch 22: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3092 - accuracy: 0.8811 - val_loss: 0.2042 - val_accuracy: 0.9105 - lr: 4.0000e-06
# Epoch 23/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3098 - accuracy: 0.8573
# Epoch 23: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.3098 - accuracy: 0.8573 - val_loss: 0.2039 - val_accuracy: 0.9053 - lr: 4.0000e-06
# Epoch 24/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3345 - accuracy: 0.8481
# Epoch 24: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.3345 - accuracy: 0.8481 - val_loss: 0.2028 - val_accuracy: 0.9053 - lr: 4.0000e-06
# Epoch 25/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.8653
# Epoch 25: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 25: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3029 - accuracy: 0.8653 - val_loss: 0.1945 - val_accuracy: 0.9105 - lr: 4.0000e-06
# Epoch 26/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2925 - accuracy: 0.8653
# Epoch 26: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 316ms/step - loss: 0.2925 - accuracy: 0.8653 - val_loss: 0.1915 - val_accuracy: 0.9105 - lr: 8.0000e-07
# Epoch 27/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3114 - accuracy: 0.8785
# Epoch 27: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 316ms/step - loss: 0.3114 - accuracy: 0.8785 - val_loss: 0.1911 - val_accuracy: 0.9105 - lr: 8.0000e-07
# Epoch 28/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2905 - accuracy: 0.8771
# Epoch 28: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2905 - accuracy: 0.8771 - val_loss: 0.1929 - val_accuracy: 0.9053 - lr: 8.0000e-07
# Epoch 29/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2962 - accuracy: 0.8877
# Epoch 29: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 322ms/step - loss: 0.2962 - accuracy: 0.8877 - val_loss: 0.1923 - val_accuracy: 0.9105 - lr: 8.0000e-07
# Epoch 30/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.8798
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 30: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 328ms/step - loss: 0.2988 - accuracy: 0.8798 - val_loss: 0.1933 - val_accuracy: 0.9105 - lr: 8.0000e-07
# Epoch 31/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2789 - accuracy: 0.8785
# Epoch 31: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2789 - accuracy: 0.8785 - val_loss: 0.1939 - val_accuracy: 0.9053 - lr: 1.6000e-07
# Epoch 32/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2777 - accuracy: 0.8838
# Epoch 32: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2777 - accuracy: 0.8838 - val_loss: 0.1943 - val_accuracy: 0.9053 - lr: 1.6000e-07
# Epoch 33/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.8573
# Epoch 33: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3221 - accuracy: 0.8573 - val_loss: 0.1948 - val_accuracy: 0.9053 - lr: 1.6000e-07
# Epoch 34/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2805 - accuracy: 0.8692
# Epoch 34: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2805 - accuracy: 0.8692 - val_loss: 0.1944 - val_accuracy: 0.9053 - lr: 1.6000e-07
# Epoch 35/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.8745
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 35: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3029 - accuracy: 0.8745 - val_loss: 0.1948 - val_accuracy: 0.9053 - lr: 1.6000e-07
# Epoch 36/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.9128
# Epoch 36: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2665 - accuracy: 0.9128 - val_loss: 0.1943 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 37/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2925 - accuracy: 0.8877
# Epoch 37: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2925 - accuracy: 0.8877 - val_loss: 0.1936 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 38/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3191 - accuracy: 0.8732
# Epoch 38: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3191 - accuracy: 0.8732 - val_loss: 0.1920 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 39/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2741 - accuracy: 0.8785
# Epoch 39: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2741 - accuracy: 0.8785 - val_loss: 0.1920 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 40/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8719
# Epoch 40: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2799 - accuracy: 0.8719 - val_loss: 0.1943 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 41/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.8890
# Epoch 41: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3001 - accuracy: 0.8890 - val_loss: 0.1949 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 42/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2903 - accuracy: 0.8785
# Epoch 42: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2903 - accuracy: 0.8785 - val_loss: 0.1938 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 43/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2928 - accuracy: 0.8930
# Epoch 43: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2928 - accuracy: 0.8930 - val_loss: 0.1936 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 44/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2943 - accuracy: 0.8798
# Epoch 44: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.2943 - accuracy: 0.8798 - val_loss: 0.1938 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 45/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2824 - accuracy: 0.8838
# Epoch 45: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2824 - accuracy: 0.8838 - val_loss: 0.1942 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 46/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8877
# Epoch 46: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2832 - accuracy: 0.8877 - val_loss: 0.1935 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 47/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2930 - accuracy: 0.8785
# Epoch 47: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2930 - accuracy: 0.8785 - val_loss: 0.1937 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 48/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.8613
# Epoch 48: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 328ms/step - loss: 0.2987 - accuracy: 0.8613 - val_loss: 0.1921 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 49/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3207 - accuracy: 0.8600
# Epoch 49: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3207 - accuracy: 0.8600 - val_loss: 0.1912 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 50/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.8771
# Epoch 50: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3059 - accuracy: 0.8771 - val_loss: 0.1907 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 51/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.8771
# Epoch 51: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2922 - accuracy: 0.8771 - val_loss: 0.1926 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 52/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3363 - accuracy: 0.8375
# Epoch 52: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 316ms/step - loss: 0.3363 - accuracy: 0.8375 - val_loss: 0.1945 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 53/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.8666
# Epoch 53: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.3175 - accuracy: 0.8666 - val_loss: 0.1938 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 54/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3180 - accuracy: 0.8785
# Epoch 54: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.3180 - accuracy: 0.8785 - val_loss: 0.1919 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 55/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2977 - accuracy: 0.8626
# Epoch 55: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 327ms/step - loss: 0.2977 - accuracy: 0.8626 - val_loss: 0.1911 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 56/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2821 - accuracy: 0.8771
# Epoch 56: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2821 - accuracy: 0.8771 - val_loss: 0.1921 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 57/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2886 - accuracy: 0.8732
# Epoch 57: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2886 - accuracy: 0.8732 - val_loss: 0.1931 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 58/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.8758
# Epoch 58: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 327ms/step - loss: 0.2862 - accuracy: 0.8758 - val_loss: 0.1934 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 59/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.8771
# Epoch 59: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2889 - accuracy: 0.8771 - val_loss: 0.1938 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 60/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3185 - accuracy: 0.8653
# Epoch 60: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 330ms/step - loss: 0.3185 - accuracy: 0.8653 - val_loss: 0.1916 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 61/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.8838
# Epoch 61: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.2692 - accuracy: 0.8838 - val_loss: 0.1908 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 62/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2972 - accuracy: 0.8600
# Epoch 62: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 328ms/step - loss: 0.2972 - accuracy: 0.8600 - val_loss: 0.1902 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 63/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.9075
# Epoch 63: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2504 - accuracy: 0.9075 - val_loss: 0.1917 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 64/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.8771
# Epoch 64: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 327ms/step - loss: 0.2920 - accuracy: 0.8771 - val_loss: 0.1915 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 65/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.8666
# Epoch 65: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.2982 - accuracy: 0.8666 - val_loss: 0.1926 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 66/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2843 - accuracy: 0.8798
# Epoch 66: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2843 - accuracy: 0.8798 - val_loss: 0.1923 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 67/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.8877
# Epoch 67: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2647 - accuracy: 0.8877 - val_loss: 0.1920 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 68/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8798
# Epoch 68: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 328ms/step - loss: 0.2885 - accuracy: 0.8798 - val_loss: 0.1903 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 69/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2940 - accuracy: 0.8666
# Epoch 69: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2940 - accuracy: 0.8666 - val_loss: 0.1910 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 70/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2771 - accuracy: 0.8771
# Epoch 70: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.2771 - accuracy: 0.8771 - val_loss: 0.1911 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 71/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3134 - accuracy: 0.8626
# Epoch 71: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3134 - accuracy: 0.8626 - val_loss: 0.1916 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 72/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.8890
# Epoch 72: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2874 - accuracy: 0.8890 - val_loss: 0.1915 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 73/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.8692
# Epoch 73: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 328ms/step - loss: 0.2835 - accuracy: 0.8692 - val_loss: 0.1916 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 74/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2704 - accuracy: 0.8956
# Epoch 74: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2704 - accuracy: 0.8956 - val_loss: 0.1921 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 75/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2900 - accuracy: 0.8692
# Epoch 75: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 328ms/step - loss: 0.2900 - accuracy: 0.8692 - val_loss: 0.1937 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 76/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.8705
# Epoch 76: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3060 - accuracy: 0.8705 - val_loss: 0.1926 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 77/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2824 - accuracy: 0.8811
# Epoch 77: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 328ms/step - loss: 0.2824 - accuracy: 0.8811 - val_loss: 0.1909 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 78/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.8824
# Epoch 78: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 329ms/step - loss: 0.2739 - accuracy: 0.8824 - val_loss: 0.1913 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 79/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.8890
# Epoch 79: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2906 - accuracy: 0.8890 - val_loss: 0.1904 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 80/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2743 - accuracy: 0.8798
# Epoch 80: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2743 - accuracy: 0.8798 - val_loss: 0.1914 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 81/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.8983
# Epoch 81: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2729 - accuracy: 0.8983 - val_loss: 0.1914 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 82/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8626
# Epoch 82: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3119 - accuracy: 0.8626 - val_loss: 0.1895 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 83/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3177 - accuracy: 0.8653
# Epoch 83: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3177 - accuracy: 0.8653 - val_loss: 0.1913 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 84/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3020 - accuracy: 0.8692
# Epoch 84: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3020 - accuracy: 0.8692 - val_loss: 0.1912 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 85/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3008 - accuracy: 0.8705
# Epoch 85: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3008 - accuracy: 0.8705 - val_loss: 0.1903 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 86/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3331 - accuracy: 0.8639
# Epoch 86: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3331 - accuracy: 0.8639 - val_loss: 0.1910 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 87/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2876 - accuracy: 0.8824
# Epoch 87: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 330ms/step - loss: 0.2876 - accuracy: 0.8824 - val_loss: 0.1914 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 88/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3278 - accuracy: 0.8666
# Epoch 88: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.3278 - accuracy: 0.8666 - val_loss: 0.1914 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 89/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3133 - accuracy: 0.8653
# Epoch 89: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.3133 - accuracy: 0.8653 - val_loss: 0.1921 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 90/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2756 - accuracy: 0.8864
# Epoch 90: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2756 - accuracy: 0.8864 - val_loss: 0.1927 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 91/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2846 - accuracy: 0.8719
# Epoch 91: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.2846 - accuracy: 0.8719 - val_loss: 0.1896 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 92/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3196 - accuracy: 0.8639
# Epoch 92: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 328ms/step - loss: 0.3196 - accuracy: 0.8639 - val_loss: 0.1901 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 93/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2888 - accuracy: 0.8890
# Epoch 93: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.2888 - accuracy: 0.8890 - val_loss: 0.1898 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 94/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8547
# Epoch 94: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 328ms/step - loss: 0.3328 - accuracy: 0.8547 - val_loss: 0.1887 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 95/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.8851
# Epoch 95: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 318ms/step - loss: 0.2692 - accuracy: 0.8851 - val_loss: 0.1893 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 96/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2923 - accuracy: 0.8811
# Epoch 96: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 317ms/step - loss: 0.2923 - accuracy: 0.8811 - val_loss: 0.1903 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 97/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2996 - accuracy: 0.8732
# Epoch 97: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 328ms/step - loss: 0.2996 - accuracy: 0.8732 - val_loss: 0.1919 - val_accuracy: 0.9053 - lr: 1.0000e-07
# Epoch 98/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2957 - accuracy: 0.8719
# Epoch 98: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 323ms/step - loss: 0.2957 - accuracy: 0.8719 - val_loss: 0.1909 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 99/100
# 48/47 [==============================] - ETA: 0s - loss: 0.2983 - accuracy: 0.8758
# Epoch 99: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 15s 319ms/step - loss: 0.2983 - accuracy: 0.8758 - val_loss: 0.1910 - val_accuracy: 0.9105 - lr: 1.0000e-07
# Epoch 100/100
# 48/47 [==============================] - ETA: 0s - loss: 0.3169 - accuracy: 0.8573
# Epoch 100: val_accuracy did not improve from 0.92632
# 47/47 [==============================] - 16s 329ms/step - loss: 0.3169 - accuracy: 0.8573 - val_loss: 0.1918 - val_accuracy: 0.9105 - lr: 1.0000e-07

# %%
with open('history.json', 'w') as f:
    json.dump(str(history.history), f)

# %%
history_df = pd.DataFrame(history.history)
history_df[['accuracy','val_accuracy']].plot()

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()

# %% [markdown]
# # Prediction

# %%
model.load_weights("weights.best.hdf5")

# %%
Y_val_pred = model.predict(x_val)
# Out:
# 6/6 [==============================] - 4s 143ms/step

# %%
accuracy_score(np.argmax(y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.9263157894736842

# %%
Y_pred = model.predict(X_test)
# Out:
# 30/30 [==============================] - 4s 133ms/step

# %%
tta_steps = 10
predictions = []

for i in tqdm(range(tta_steps)):
    preds = model.predict_generator(train_generator.flow(X_test, batch_size=BATCH_SIZE, shuffle=False),
                                    steps = len(X_test)/BATCH_SIZE)
    
    predictions.append(preds)
    gc.collect()
    
Y_pred_tta = np.mean(predictions, axis=0)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#
# 100%|██████████| 10/10 [01:55<00:00, 11.52s/it]

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Breast Cancer')
# Out:
# Confusion matrix, without normalization
# [[512  14]
#  [ 40 381]]

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.92      0.96      0.94       526\n           1       0.94      0.89      0.92       421\n\n    accuracy                           0.93       947\n   macro avg       0.93      0.92      0.93       947\nweighted avg       0.93      0.93      0.93       947\n'

# %% [markdown]
# ### ROC and AUC

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')#Receiver Operating characteristics
plt.close()

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(Y_test)):
    if(np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(Y_test)):
    if(not np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# # Display first 8 images of benign
w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(Y_pred_tta[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(Y_test[prop_class[i]])))
    plt.imshow(X_test[prop_class[i]], interpolation='nearest')
plt.show()
